# %%
import pandas as pd
import numpy as np
import sqlite3 as sql

# %%
capitals = pd.read_csv('data/capitals.csv')
countries = pd.read_csv('data/countries.csv')
movies = pd.read_csv('data/movies.csv')
conn = sql.connect('data/database.db')

# %%
capitals.to_sql('Capitals',conn,if_exists='replace',index=False)

# %%
countries.to_sql('Countries',conn,if_exists='replace',index=False)
# Out:
# C:\Users\Mourad Bouguerra\anaconda3\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %%
movies.to_sql('Movies',conn,if_exists='replace',index=False)

# %%
display(capitals.head(),countries.head(),movies.head())
# Out:
#                  Country              Capital
# 0               Abkhazia              Sukhumi
# 1            Afghanistan                Kabul
# 2  Akrotiri and Dhekelia  Episkopi Cantonment
# 3                Albania               Tirana
# 4                Algeria              Algiers
#       Country     Country Code 2CHAR Country Code 3CHAR Continent
# 0     Afghanistan                 AF                AFG      Asia
# 1   Åland Islands                 AX                ALA    Europe
# 2         Albania                 AL                ALB    Europe
# 3         Algeria                 DZ                DZA    Africa
# 4  American Samoa                 AS                ASM   Oceania
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# ...

# %%
conn = sql.connect('data/database.db')
cursor = conn.cursor()

# %%
sql_stmt = 'SELECT * FROM COUNTRIES WHERE Continent=="Africa"'
rows = cursor.execute(sql_stmt)
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#                                      Country     Country Code 2CHAR  \
# 0                                        Algeria                 DZ
# 1                                         Angola                 AO
# 2                                          Benin                 BJ
# 3                                       Botswana                 BW
# 4                                   Burkina Faso                 BF
# 5                                        Burundi                 BI
# 6                                       Cameroon                 CM
# 7                                     Cabo Verde                 CV
# 8                       Central African Republic                 CF
# 9                                           Chad                 TD
# 10                                       Comoros                 KM
# 11                                         Congo                 CG
# 12            Congo (Democratic Republic of the)                 CD
# ...
